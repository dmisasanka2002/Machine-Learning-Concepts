# %% [markdown]
# Run Linear/Ridge/Lasso/Elastic Net/Decision Tree/Random Forest/Gradient
# Boosting on `datasets/insurance.csv` (real repo dataset). Report MAE, RMSE,
# $R^2$, training time — same pattern as
# `_scripts/plot_algorithm_comparison_tables.py`, adapted to regression
# metrics (`mean_absolute_error`, `mean_squared_error`, `r2_score`).

# %% [markdown]
# ![bias-variance tradeoff](../_assets/bias_variance_tradeoff.png)
#
# *(Generated by `../_scripts/plot_algorithm_comparison_tables.py`.)*
