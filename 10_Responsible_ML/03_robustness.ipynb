# %% [markdown]
# Model performance under distribution shift or adversarial perturbation.
# Brief mention of adversarial examples (small, often imperceptible input
# perturbations that flip a model's prediction) as a robustness failure
# mode; connects to why margin-maximizing methods like SVM have some
# built-in geometric robustness intuition (points far from the decision
# boundary are harder to flip) vs. models with no explicit margin concept.
